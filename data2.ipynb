# %%
import pandas as pd

# %%
ufo= pd.read_csv('http://bit.ly/uforeports')

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
type(ufo)
# Out:
# pandas.core.frame.DataFrame

# %%
ufo['City']
# Out:
# 0                      Ithaca
# 1                 Willingboro
# 2                     Holyoke
# 3                     Abilene
# 4        New York Worlds Fair
# 5                 Valley City
# 6                 Crater Lake
# 7                        Alma
# 8                     Eklutna
# 9                     Hubbard
# 10                    Fontana
# 11                   Waterloo
# 12                     Belton
# 13                     Keokuk
# 14                  Ludington
# 15                Forest Home
# 16                Los Angeles
# 17                  Hapeville
# 18                     Oneida
# 19                 Bering Sea
# 20                   Nebraska
# 21                        NaN
# 22                        NaN
# 23                  Owensboro
# 24                 Wilderness
# 25                  San Diego
# 26                 Wilderness
# 27                     Clovis
# 28                 Los Alamos
# 29               Ft. Duschene
#                  ...
# ...

# %%
ufo['Shape Reported']
# Out:
# 0         TRIANGLE
# 1            OTHER
# 2             OVAL
# 3             DISK
# 4            LIGHT
# 5             DISK
# 6           CIRCLE
# 7             DISK
# 8            CIGAR
# 9         CYLINDER
# 10           LIGHT
# 11        FIREBALL
# 12          SPHERE
# 13            OVAL
# 14            DISK
# 15          CIRCLE
# 16             NaN
# 17             NaN
# 18       RECTANGLE
# 19           OTHER
# 20            DISK
# 21             NaN
# 22           LIGHT
# 23       RECTANGLE
# 24            DISK
# 25           CIGAR
# 26            DISK
# 27            DISK
# 28            DISK
# 29            DISK
#            ...
# 18211      DIAMOND
# 18212         DISK
# 18213     FIREBALL
# 18214    FORMATION
# 18215        OTHER
# 18216        LIGHT
# 18217     TRIANGLE
# 18218      DIAMOND
# 18219      CHEVRON
# 18220         DISK
# 18221         DISK
# 18222        OTHER
# 18223          NaN
# 18224         DISK
# 18225    FORMATION
# 18226    FORMATION
# ...

# %%
type(ufo['Shape Reported'])
# Out:
# pandas.core.series.Series

# %%
ufo.City
# Out:
# 0                      Ithaca
# 1                 Willingboro
# 2                     Holyoke
# 3                     Abilene
# 4        New York Worlds Fair
# 5                 Valley City
# 6                 Crater Lake
# 7                        Alma
# 8                     Eklutna
# 9                     Hubbard
# 10                    Fontana
# 11                   Waterloo
# 12                     Belton
# 13                     Keokuk
# 14                  Ludington
# 15                Forest Home
# 16                Los Angeles
# 17                  Hapeville
# 18                     Oneida
# 19                 Bering Sea
# 20                   Nebraska
# 21                        NaN
# 22                        NaN
# 23                  Owensboro
# 24                 Wilderness
# 25                  San Diego
# 26                 Wilderness
# 27                     Clovis
# 28                 Los Alamos
# 29               Ft. Duschene
#                  ...
# ...

# %%
ufo.State
# Out:
# 0        NY
# 1        NJ
# 2        CO
# 3        KS
# 4        NY
# 5        ND
# 6        CA
# 7        MI
# 8        AK
# 9        OR
# 10       CA
# 11       AL
# 12       SC
# 13       IA
# 14       MI
# 15       CA
# 16       CA
# 17       GA
# 18       TN
# 19       AK
# 20       NE
# 21       LA
# 22       LA
# 23       KY
# 24       WV
# 25       CA
# 26       WV
# 27       NM
# 28       NM
# 29       UT
#          ..
# 18211    MA
# 18212    CA
# 18213    CA
# 18214    TX
# 18215    TX
# 18216    CA
# 18217    CO
# 18218    TX
# 18219    CA
# 18220    CA
# 18221    NH
# 18222    PA
# 18223    SC
# 18224    OK
# 18225    CA
# 18226    CA
# 18227    CA
# 18228    TX
# 18229    IL
# 18230    CA
# 18231    CA
# 18232    WI
# 18233    AK
# 18234    CA
# 18235    AZ
# 18236    IL
# 18237    IA
# 18238    WI
# 18239    WI
# 18240    FL
# Name: State, Length: 18241, dtype: object

# %%
ufo.shape
# Out:
# (18241, 5)

# %%
ufo.City + ufo.State
# Out:
# 0                      IthacaNY
# 1                 WillingboroNJ
# 2                     HolyokeCO
# 3                     AbileneKS
# 4        New York Worlds FairNY
# 5                 Valley CityND
# 6                 Crater LakeCA
# 7                        AlmaMI
# 8                     EklutnaAK
# 9                     HubbardOR
# 10                    FontanaCA
# 11                   WaterlooAL
# 12                     BeltonSC
# 13                     KeokukIA
# 14                  LudingtonMI
# 15                Forest HomeCA
# 16                Los AngelesCA
# 17                  HapevilleGA
# 18                     OneidaTN
# 19                 Bering SeaAK
# 20                   NebraskaNE
# 21                          NaN
# 22                          NaN
# 23                  OwensboroKY
# 24                 WildernessWV
# 25                  San DiegoCA
# 26                 WildernessWV
# 27                     ClovisNM
# 28                 Los AlamosNM
# ...

# %%
ufo['location']= ufo.City +', ' + ufo.State

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time  \
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
#
#                    location
# 0                Ithaca, NY
# 1           Willingboro, NJ
# 2               Holyoke, CO
# 3               Abilene, KS
# 4  New York Worlds Fair, NY

# %%
ufo['Shape/Time']= ufo['Shape Reported'] + ufo.Time

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time  \
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
#
#                    location              Shape/Time
# 0                Ithaca, NY  TRIANGLE6/1/1930 22:00
# 1           Willingboro, NJ    OTHER6/30/1930 20:00
# 2               Holyoke, CO     OVAL2/15/1931 14:00
# 3               Abilene, KS      DISK6/1/1931 13:00
# 4  New York Worlds Fair, NY    LIGHT4/18/1933 19:00

# %%
ufo['city/time']= ufo.City + ufo.Time

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time  \
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
#
#                    location              Shape/Time  \
# 0                Ithaca, NY  TRIANGLE6/1/1930 22:00
# 1           Willingboro, NJ    OTHER6/30/1930 20:00
# 2               Holyoke, CO     OVAL2/15/1931 14:00
# 3               Abilene, KS      DISK6/1/1931 13:00
# 4  New York Worlds Fair, NY    LIGHT4/18/1933 19:00
#
#                              city/time
# 0                 Ithaca6/1/1930 22:00
# 1           Willingboro6/30/1930 20:00
# 2               Holyoke2/15/1931 14:00
# ...
